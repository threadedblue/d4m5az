# %%
using CSV, D4M, Plots

# %%
x = 1:10; y = rand(10); # These are the plotting data 
plot(x,y, label="my label")

# %%
d = CSV.read("numB.csv")
# Out:
# 3×9 DataFrame. Omitted printing of 1 columns
# │ Row │ Column1 │ ca    │ cb    │ cc    │ cd    │ ce    │ da    │ db    │
# │     │ String  │ Int64 │ Int64 │ Int64 │ Int64 │ Int64 │ Int64 │ Int64 │
# ├─────┼─────────┼───────┼───────┼───────┼───────┼───────┼───────┼───────┤
# │ 1   │ r1      │ 1     │ 11    │ 21    │ 31    │ 2     │ 1     │ 2     │
# │ 2   │ r2      │ 1     │ 0     │ 0     │ 1     │ 1     │ 1     │ 1     │
# │ 3   │ r3      │ 1     │ 1     │ 1     │ 1     │ 1     │ 1     │ 1     │

# %%
bar(d.ca, [d.cb, d.cc, d.cd, d.ce, d.da])

# %%
dd = CSV.read("ccd1.csv")

# %%
bar(d.ca, [d.cb, d.cc, d.cd, d.ce, d.da])
